# %%
print("Меня зовут Варя, и я готова страдать на курсе!")
# Out:
# Меня зовут Варя, и я готова страдать на курсе!

# %% [markdown]
# ![telegram-cloud-photo-size-2-5197491924238465101-y.jpg](attachment:telegram-cloud-photo-size-2-5197491924238465101-y.jpg)

# %% [markdown]
# ### О себе
#
# Привет, меня зовут Варя. Несколько фактов обо мне:
# * Закончилась Бизнес-информатику в Финансовом университете
# * Работаю в банке аналитиком
# * Играю в волейбол

# %%
77%2
# Out:
# 1

# %%
if (22%2==0):
    print('Число чётное')
else:
    print('Число нечётное')
# Out:
# Число чётное

# %%
86**7
# Out:
# 34792782221696

# %%
import math 

math.sqrt(3686400)
# Out:
# 1920.0

# %%
3686400**0.5
# Out:
# 1920.0
